# %%
'''
Chỉnh working directory, k cần quan tâm lắm :))
'''

import sys
from pathlib import Path
# Add the project root directory (one level up from tests/)
sys.path.append(str(Path.cwd().parent))
import pandas as pd
import os

# %%
'''
Load các thư viện, function cần thiết.
    producer_config: cài đặt filter do chuyên viên nhập và điều chỉnh
    LoadMedicalData: class sử dụng để load, xử lý và tính toán
'''
# %load_ext autoreload
# %autoreload 2

from config.filter_config import producer_config
from src.utils.data_loader import LoadMedicalData
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
'''
Đoạn này thử đưa một đoạn dữ liệu vào để load. Sau khi chạy xong thì dữ liệu raw sẽ được lưu trong 'test_data'. Người dùng có thể thực hiện filter hoặc tính tổng từ đây.
'''

test_path = r'..\data\raw\data_Duoc_full\raw\kqtt\202504-202505.xls'
test_data = LoadMedicalData(
    test_path, 
    config=producer_config # Phần config này về sau sẽ cần mở rộng cho các dạng filter khác, hiện tại đang mới có filter dành cho 'nhasx'
)

# %%
# Hiển thị toàn bộ dữ liệu raw
test_data.show_data()
# Out:
#              loai_thau      ma                       ten  \
# 0      3.thau_rieng_le  40.162         SM.Cefadroxil 500
# 1      3.thau_rieng_le  40.883         Natri Clorid 0,9%
# 2      3.thau_rieng_le  40.883         Natri Clorid 0,9%
# 3      3.thau_rieng_le  40.512          SaVi Losartan 50
# 4      3.thau_rieng_le  40.883         Natri Clorid 0,9%
# ...                ...     ...                       ...
# 41467  3.thau_rieng_le  40.219             Azicine 250mg
# 41468  3.thau_rieng_le  40.521  Amlessa 4mg/10mg Tablets
# 41469  3.thau_rieng_le  40.609                 Fucidin H
# 41470  3.thau_rieng_le  40.609                 Fucidin H
# 41471  3.thau_rieng_le    笂Ѐ騖ʹ                  Tobradex
#
#                            hoatchat ma_tinh       ten_tinh  \
# 0                        Cefadroxil      27  Tỉnh Bắc Ninh
# 1                      Natri clorid      27  Tỉnh Bắc Ninh
# 2                      Natri clorid      27  Tỉnh Bắc Ninh
# 3                     Losartan Kali      27  Tỉnh Bắc Ninh
# 4                      Natri clorid      27  Tỉnh Bắc Ninh
# ...                             ...     ...            ...
# 41467                  Azithromycin      10   Tỉnh Lào Cai
# 41468       Perindopril + amlodipin      10   Tỉnh Lào Cai
# 41469  Fusidic acid + hydrocortison      10   Tỉnh Lào Cai
# 41470  Fusidic acid + hydrocortison      10   Tỉnh Lào Cai
# 41471     Tobramycin + dexamethason      10   Tỉnh Lào Cai
#
#                    ten_don_vi ma_cskcb               ten_cskcb   ma_gy  ...  \
# 0                 Tyt An Bình    27112             Tyt An Bình  40.162  ...
# 1                 Tyt An Bình    27112             Tyt An Bình  40.883  ...
# 2                 Tyt An Bình    27112             Tyt An Bình  40.883  ...
# 3                 Tyt An Bình    27112             Tyt An Bình  40.512  ...
# 4                 Tyt An Bình    27112             Tyt An Bình  40.883  ...
# ...                       ...      ...                     ...     ...  ...
# 41467  Bvđk Số 4 Tỉnh Lào Cai    10009  Bvđk Số 4 Tỉnh Lào Cai  40.219  ...
# 41468  Bvđk Số 4 Tỉnh Lào Cai    10009  Bvđk Số 4 Tỉnh Lào Cai  40.521  ...
# 41469  Bvđk Số 4 Tỉnh Lào Cai    10009  Bvđk Số 4 Tỉnh Lào Cai  40.609  ...
# 41470  Bvđk Số 4 Tỉnh Lào Cai    10009  Bvđk Số 4 Tỉnh Lào Cai  40.609  ...
# 41471  Bvđk Số 4 Tỉnh Lào Cai    10009  Bvđk Số 4 Tỉnh Lào Cai  40.207  ...
#
#            loai sttpheduyet hieuluc ht_thau created_date tungay denngay  \
# 0      Tân dược        None       1       1         None   None    None
# 1      Tân dược        None       1       1         None   None    None
# 2      Tân dược        None       1       1         None   None    None
# 3      Tân dược        None       1       1         None   None    None
# 4      Tân dược        None       1       1         None   None    None
# ...         ...         ...     ...     ...          ...    ...     ...
# 41467  Tân dược        None       1       1         None   None    None
# 41468  Tân dược        None       1       1         None   None    None
# 41469  Tân dược        None       1       1         None   None    None
# 41470  Tân dược        None       1       1         None   None    None
# 41471       NaN        None     NaN     NaN         None   None    None
#
#       congbo tungay_hd denngay_hd
# 0       None      None       None
# 1       None      None       None
# 2       None      None       None
# 3       None      None       None
# 4       None      None       None
# ...      ...       ...        ...
# 41467   None      None       None
# 41468   None      None       None
# 41469   None      None       None
# 41470   None      None       None
# 41471   None      None       None
#
# [41472 rows x 38 columns]

# %%
# Filter dữ liệu tùy theo config đưa vào
test_data.filter().show_data() # Nếu để trống phần filter sẽ trả về toàn bộ các mục mà được liệt kê trong config
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[27], line 2
#       1 # Filter dữ liệu tùy theo config đưa vào
# ----> 2 test_data.filter().show_data() # Nếu để trống phần filter sẽ trả về toàn bộ các mục mà được liệt kê trong config
#
# File c:\Users\ducngh\OneDrive - fpts.com.vn\Work\Dược\src\utils\data_loader.py:11, in filter(self, by, verbose)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File c:\Users\ducngh\OneDrive - fpts.com.vn\Work\Dược\src\utils\data_loader.py:12, in __init__(self, datasource, category, config)
#       9 from pydantic import TypeAdapter
#      10 from typing import Literal
# ---> 12 def validate_medical_df(
#      13     df: pd.DataFrame, return_as: str = "df"
#      14 ) -> Union[pd.DataFrame, list[MedicineRecord]]:
#      15   """Validates DataFrame rows against MedicineRecord schema.
#      16
#      17   Args:
#    (...)     20         list[MedicineRecord]
#      21   """
#      22   adapter = TypeAdapter(list[MedicineRecord])
#
# KeyError: 'producer'

# %%
# Filter ra một mục tùy chọn
test_data.filter(by='IMP').show_data()
# Out:
#            loai_thau      ma                                            ten  \
# 0    3.thau_rieng_le  40.158                                   Nerusyn 1,5g
# 1    3.thau_rieng_le  40.161                                    Imeclor 125
# 2    3.thau_rieng_le  40.162                                Imedroxil 500mg
# 3    3.thau_rieng_le  40.169                                    Imexime 100
# 4    3.thau_rieng_le  40.155                   Amoxicillin 250 mg/ 31,25 mg
# ..               ...     ...                                            ...
# 757  3.thau_rieng_le  40.169                                    Imexime 100
# 758  3.thau_rieng_le  40.172                                 Bacsulfo 1g/1g
# 759  3.thau_rieng_le  40.155  Amoxicillin/ Acid clavulanic 250 mg/ 31,25 mg
# 760  3.thau_rieng_le  40.171                              Cefoperazone 0,5g
# 761  3.thau_rieng_le  40.174                                     Cefotiam1g
#
#                          hoatchat ma_tinh          ten_tinh  \
# 0           Ampicilin + sulbactam      11    Tỉnh Điện Biên
# 1                        Cefaclor      60   Tỉnh Bình Thuận
# 2                      Cefadroxil      94    Tỉnh Sóc Trăng
# 3                         Cefixim      82   Tỉnh Tiền Giang
# 4    Amoxicilin + acid clavulanic      01  Thành phố Hà Nội
# ..                            ...     ...               ...
# 757                       Cefixim      26    Tỉnh Vĩnh Phúc
# 758      Cefoperazon + sulbactam*      01  Thành phố Hà Nội
# 759  Amoxicilin + acid clavulanic      10      Tỉnh Lào Cai
# 760                  Cefoperazon*      01  Thành phố Hà Nội
# 761                     Cefotiam*      01  Thành phố Hà Nội
#
#                                         ten_don_vi ma_cskcb  \
# 0                               Ttyt Điện Biên Phủ    11002
# 1                                        Tyt Đa Mi    60097
# 2                                 Tyt Trường Khánh    94132
# 3    Pkđk Dưỡng Điềm Thuộc Ttyt Khu Vực Châu Thành    82025
# 4           Pkđkkv Liên Hồng Trực Thuộc Tyt Ô Diên    01839
# ..                                             ...      ...
# 757                           Ttyt Khu Vực Tam Đảo    26026
# 758                                  Bvđk Vân Đình    01817
# 759                         Bvđk Số 4 Tỉnh Lào Cai    10009
# 760                               Bvđk Nông Nghiệp    01013
# 761                               Bvđk Nông Nghiệp    01013
#
#                                          ten_cskcb   ma_gy  ... sttpheduyet  \
# 0                               Ttyt Điện Biên Phủ  40.158  ...        None
# 1                                        Tyt Đa Mi  40.161  ...        None
# 2                                 Tyt Trường Khánh  40.162  ...        None
# 3    Pkđk Dưỡng Điềm Thuộc Ttyt Khu Vực Châu Thành  40.169  ...        None
# 4           Pkđkkv Liên Hồng Trực Thuộc Tyt Ô Diên  40.155  ...        None
# ..                                             ...     ...  ...         ...
# 757                           Ttyt Khu Vực Tam Đảo  40.169  ...        None
# 758                                  Bvđk Vân Đình  40.172  ...        None
# 759                         Bvđk Số 4 Tỉnh Lào Cai  40.155  ...        None
# 760                               Bvđk Nông Nghiệp  40.171  ...        None
# 761                               Bvđk Nông Nghiệp  40.174  ...        None
#
#     hieuluc ht_thau created_date tungay denngay congbo tungay_hd denngay_hd  \
# 0         1       1         None   None    None   None      None       None
# 1         1       5         None   None    None   None      None       None
# 2         1       4         None   None    None   None      None       None
# 3         1       1         None   None    None   None      None       None
# 4         1       1         None   None    None   None      None       None
# ..      ...     ...          ...    ...     ...    ...       ...        ...
# 757       1       1         None   None    None   None      None       None
# 758       1       1         None   None    None   None      None       None
# 759       1       1         None   None    None   None      None       None
# 760       1       1         None   None    None   None      None       None
# 761       1       1         None   None    None   None      None       None
#
#     ticker
# 0      IMP
# 1      IMP
# 2      IMP
# 3      IMP
# 4      IMP
# ..     ...
# 757    IMP
# 758    IMP
# 759    IMP
# 760    IMP
# 761    IMP
#
# [762 rows x 39 columns]

# %%
# Tính tổng số lượng
print(f'Tổng số lượng của IMP: {test_data.filter(by='IMP').sum(value_col='soluong'):,.0f}') # Cái ':,.0f' là để hiển thị dấu phẩy hàng nghìn
 
# Tính tổng giá trị
print(f'Tổng giá trị của IMP: {test_data.filter(by='IMP').sum(value_col='thanhtien'):,.0f}')
# Out:
# Tổng số lượng của IMP: 25,647,070
# Tổng giá trị của IMP: 288,706,927,665
